# %% [markdown]
# # Instituto Tecnológico Superior de San Luis Potosí, Capital.

# %% [markdown]
# ## Taller de Git, GitHub, MarkDown y Python¶
# ## ITSSLPC-ISC
# #### Actividades complementarias

# %%
print("Hola Mundo !!!")
# Out:
# Hola Mundo !!!

# %%
# concatena el valor de x
x = input("Dame el valor de x: ")
w = x + x
print(w)
# Out:
# Dame el valor de x:  10
# 1010

# %%
# convierte el valor de x a flotante
x = float(input("Dame el valor de x: "))
w = x + x
print(w)
# Out:
# Dame el valor de x:  20
# 40.0

# %% [markdown]
# **Uso del IF**

# %%
# if simple

# asignación de un valor a x
x = 20.000

if x == 20:
    print("El valor de x es 20 ")
# Out:
# El valor de x es 20

# %%
# if simple

# asignación de un valor a x
x = 20.01

if x == 20:
    print("El valor de x es 20 ")

# %% [markdown]
# Carlos Daniel Rodriguez Rosales
